# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      belyy yar  53.6039   91.3903     -9.06        92           0
# 1        1     bredasdorp -34.5322   20.0403     13.09        59           0
# 2        2  port mathurin -19.6833   63.4167     24.75        79          13
# 3        3       waitangi -43.9535 -176.5597     13.23        75          14
# 4        4    yellowknife  62.4560 -114.3525     -7.55        99          17
#
#    Wind Speed Country        Date
# 0        1.00      RU  1698631679
# 1        8.89      ZA  1698631556
# 2        6.82      MU  1698631680
# 3        3.13      NZ  1698631680
# 4        1.34      CA  1698631680

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    alpha = 0.5,
    color = "City",
    tiles = "OSM",
    frame_width = 800,
    frame_height = 500
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
reduc_city_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 28) & (city_data_df["Max Temp"] > 19) \
    & (city_data_df["Wind Speed"] < 4.0) \
    & (city_data_df["Cloudiness"] == 0)
]


# Drop any rows with null values
reduc_city_df = reduc_city_df.dropna()

# Display sample data
reduc_city_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 19        19       pacific grove  36.6177 -121.9166     19.82        61
# 49        49       morehead city  34.7229  -76.7260     21.68        88
# 99        99              guiglo   6.5456   -7.4966     22.26        92
# 114      114             farshut  26.0549   32.1633     24.32        42
# 125      125             salalah  17.0151   54.0924     25.05        83
# 158      158              gebeit  21.0667   36.3167     23.00        84
# 232      232              gufeng  26.9083  118.9819     19.99        59
# 238      238              colusa  39.2143 -122.0094     19.01        17
# 242      242          fort bragg  35.1390  -79.0060     20.46        89
# 271      271             salinas  36.6777 -121.6555     20.05        45
# 273      273              leland  34.2563  -78.0447     21.01        89
# 288      288            xiaoshan  30.1675  120.2588     21.92        68
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = reduc_city_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                    City Country      Lat       Lng  Humidity Hotel Name
# 19        pacific grove      US  36.6177 -121.9166        61
# 49        morehead city      US  34.7229  -76.7260        88
# 99               guiglo      CI   6.5456   -7.4966        92
# 114             farshut      EG  26.0549   32.1633        42
# 125             salalah      OM  17.0151   54.0924        83
# 158              gebeit      SD  21.0667   36.3167        84
# 232              gufeng      CN  26.9083  118.9819        59
# 238              colusa      US  39.2143 -122.0094        17
# 242          fort bragg      US  35.1390  -79.0060        89
# 271             salinas      US  36.6777 -121.6555        45
# 273              leland      US  34.2563  -78.0447        89
# 288            xiaoshan      CN  30.1675  120.2588        68
# 293              murzuq      LY  25.9155   13.9184        28
# 298             urangan      AU -25.3000  152.9000        57
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address_data = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address_data["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# pacific grove - nearest hotel: Pacific Grove Inn
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# guiglo - nearest hotel: Hôtel Gbaoly 2
# farshut - nearest hotel: Hotel Central
# salalah - nearest hotel: Muscat International Hotel
# gebeit - nearest hotel: No hotel found
# gufeng - nearest hotel: No hotel found
# colusa - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# salinas - nearest hotel: The Traveler's Hotel
# leland - nearest hotel: Holiday Inn Express Leland - Wilmington Area
# xiaoshan - nearest hotel: 杭州凯豪大酒店
# murzuq - nearest hotel: فندق باريس - مرزق
# urangan - nearest hotel: Ramada
# lengshuitan - nearest hotel: No hotel found
# along - nearest hotel: Hotel Toshi Palace
# limassol - nearest hotel: Cornaro Fine Arts Center hotel
# tazacorte - nearest hotel: App Leyma
# umluj - nearest hotel: No hotel found
# cambria - nearest hotel: Olallieberry Inn
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 500,
    hover_cols = ["Hotel Name", "Country"]
)


# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
